# %%
# Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Data Processing
import numpy as np
import pandas as pd
import pickle
from gensim.models import Word2Vec

# NLP 
import re
import gensim
import nltk
import spacy
from nltk.corpus import stopwords
nltk.download('wordnet')

# ML
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix

# BERT
import torch
from pytorch_pretrained_bert import BertTokenizer, BertModel, BertForMaskedLM
from scipy.spatial.distance import cosine

import warnings
# Out:
# [nltk_data] Downloading package wordnet to /Users/kaushik-
# [nltk_data]     shakkari/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv('/Users/kaushik-shakkari/Downloads/counsel_chat_dataset.csv')

# %%
df.shape
# Out:
# (2271, 11)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
df.head(10)
# Out:
#    questionID                                            questionTitle  \
# 0  0           Can I change my feeling of being worthless to everyone?
# 1  0           Can I change my feeling of being worthless to everyone?
# 2  0           Can I change my feeling of being worthless to everyone?
# 3  0           Can I change my feeling of being worthless to everyone?
# 4  0           Can I change my feeling of being worthless to everyone?
# 5  0           Can I change my feeling of being worthless to everyone?
# 6  0           Can I change my feeling of being worthless to everyone?
# 7  0           Can I change my feeling of being worthless to everyone?
# 8  0           Can I change my feeling of being worthless to everyone?
# 9  0           Can I change my feeling of being worthless to everyone?
#
# ...

# %%
df = df.drop_duplicates(subset='questionTitle', keep="first")

# %%
df.shape
# Out:
# (827, 14)

# %%
df.questionTitle.nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-84b1bf921476> in <module>
# ----> 1 df.questionTitle.nunique()
#
# NameError: name 'df' is not defined

# %%
df.questionText.nunique()
# Out:
# 826

# %%
df.answerText.nunique()
# Out:
# 820

# %%
df.topic.nunique()
# Out:
# 30

# %%
fig, ax = plt.subplots(1, 1, figsize=(30,30))
df['topic'].value_counts().plot.pie( autopct = '%1.1f%%')

# %%
df.topic.value_counts()
# Out:
# depression                  134
# relationships               101
# intimacy                    100
# anxiety                     88
# family-conflict             58
# parenting                   54
# self-esteem                 42
# relationship-dissolution    31
# behavioral-change           29
# anger-management            25
# trauma                      22
# marriage                    20
# domestic-violence           16
# lgbtq                       15
# social-relationships        11
# workplace-relationships     11
# substance-abuse             10
# grief-and-loss              9
# spirituality                7
# counseling-fundamentals     7
# legal-regulatory            6
# professional-ethics         6
# sleep-improvement           5
# eating-disorders            4
# human-sexuality             4
# diagnosis                   3
# stress                      3
# addiction                   3
# children-adolescents        2
# military-issues             1
# ...

# %%
df.topic.value_counts(normalize=True).apply(lambda x:x*100).plot(kind='bar')

# %%
df.topic.value_counts().apply(lambda x:x*100).plot(kind='bar')

# %%
df.topic.value_counts(normalize=True).apply(lambda x:str(round(x*100,3))+" %")
# Out:
# depression                  16.203 %
# relationships               12.213 %
# intimacy                    12.092 %
# anxiety                     10.641 %
# family-conflict             7.013 %
# parenting                   6.53 %
# self-esteem                 5.079 %
# relationship-dissolution    3.748 %
# behavioral-change           3.507 %
# anger-management            3.023 %
# trauma                      2.66 %
# marriage                    2.418 %
# domestic-violence           1.935 %
# lgbtq                       1.814 %
# social-relationships        1.33 %
# workplace-relationships     1.33 %
# substance-abuse             1.209 %
# grief-and-loss              1.088 %
# spirituality                0.846 %
# counseling-fundamentals     0.846 %
# legal-regulatory            0.726 %
# professional-ethics         0.726 %
# sleep-improvement           0.605 %
# eating-disorders            0.484 %
# human-sexuality             0.484 %
# diagnosis                   0.363 %
# ...

# %%
#df = df[df.topic.isin(["depression","relationships","intimacy","anxiety"])]

# %%
df = df.reset_index()
df = df.drop(["index"], axis = 1)

# %%
for i in range(df.shape[0]):
    if df.loc[i,"topic"] in ["relationships","intimacy","family-conflict","parenting","relationship-dissolution","marriage","domestic-violence"]:
        df.loc[i,"parent_topic"] = "family_conflicts"
    elif df.loc[i,"topic"] in ["depression","anxiety","stress","anger-management","trauma"]:
        df.loc[i,"parent_topic"] = "emotional_conflicts"
    else:
        df.loc[i,"parent_topic"] = "others"

# %%
df.shape
# Out:
# (827, 14)

# %%
df["parent_topic"] = df["parent_topic"].astype('category')

# %%
df["labels"] = df["parent_topic"].cat.codes

# %%
df["text"] = df["questionTitle"] + " " + df["questionText"]

# %%
df.head()
# Out:
#    questionID  \
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4
#
#                                                      questionTitle  \
# 0  Can I change my feeling of being worthless to everyone?
# 1  Do I have too many issues for counseling?
# 2  How do I find out the cause of my depression and anxiety?
# 3  How do I overcome my anxierty and depression?
# 4  Why am I upset or down every day even when nothing is going on?
#
#                                                                                                                                                                                                                                                                                                                                                                                questionText  \
# ...

# %%
df.topic.value_counts()
# Out:
# depression                  134
# relationships               101
# intimacy                    100
# anxiety                     88
# family-conflict             58
# parenting                   54
# self-esteem                 42
# relationship-dissolution    31
# behavioral-change           29
# anger-management            25
# trauma                      22
# marriage                    20
# domestic-violence           16
# lgbtq                       15
# social-relationships        11
# workplace-relationships     11
# substance-abuse             10
# grief-and-loss              9
# spirituality                7
# counseling-fundamentals     7
# legal-regulatory            6
# professional-ethics         6
# sleep-improvement           5
# eating-disorders            4
# human-sexuality             4
# diagnosis                   3
# stress                      3
# addiction                   3
# children-adolescents        2
# military-issues             1
# ...

# %%
df.dtypes
# Out:
# questionID       int64
# questionTitle    object
# questionText     object
# questionLink     object
# topic            category
# therapistInfo    object
# therapistURL     object
# answerText       object
# upvotes          int64
# views            int64
# split            object
# labels           int8
# text             object
# parent_topic     category
# dtype: object

# %%
df.text = df.text.astype("str")

# %%
model = ClassificationModel('bert', 'bert-base-uncased', num_labels=3, use_cuda=False)

# %%
train_df, eval_df = train_test_split(df, test_size=0.3, random_state =333)

# %%
train_df = train_df[['text', 'labels']]
eval_df = eval_df[['text', 'labels']]

# %%
train_df = train_df.reset_index()
train_df.drop(['index'], axis = 1, inplace = True)

# %%
eval_df = eval_df.reset_index()
eval_df.drop(['index'], axis = 1, inplace = True)

# %%
def f1_multiclass(labels, preds):
    return f1_score(labels, preds, average='micro')

# %%
model.train_model(train_df, args={'learning_rate':1e-4, 'num_train_epochs': 4, 'reprocess_input_data': True, 'overwrite_output_dir': True,"train_batch_size": 14}, f1=f1_multiclass, acc=accuracy_score)
# Out:
# Converting to features started. Cache is not used.
# ...
# Running loss: 1.490024
# ...
# Running loss: 0.698988
# /Users/kaushik-shakkari/anaconda3/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:224: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Running loss: 0.748562
# ...
# Running loss: 0.061916
# ...
# Running loss: 0.020645Training of bert model complete. Saved to outputs/.

# %%
result, model_outputs, wrong_predictions = model.eval_model(eval_df, f1=f1_multiclass, acc=accuracy_score)
# Out:
# Converting to features started. Cache is not used.
# ...
# {'mcc': 0.6678674936083961, 'f1': 0.78714859437751, 'acc': 0.7871485943775101, 'eval_loss': 0.8558392685372382}

# %%
result
# Out:
# {'mcc': 0.6678674936083961,
#  'f1': 0.78714859437751,
#  'acc': 0.7871485943775101,
#  'eval_loss': 0.8558392685372382}

# %%
result['f1']
# Out:
# 0.78714859437751
